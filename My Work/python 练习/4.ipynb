# %%
import  pandas as pd
df=pd.DataFrame(pd.read_excel('grade.xlsx'))
print(df.loc[:,'语文'])
print(df.loc[3])
print(df.loc[6,'数学'])
# Out:
# 0    95
# 1    85
# 2    75
# 3    99
# 4    66
# 5    85
# 6    84
# 7    93
# 8    87
# 9    59
# Name: 语文, dtype: int64
# 语文     99
# 数学     79
# 英语     85
# 物理     69
# 总分    332
# Name: 3, dtype: int64
# 90
